# %%
import openai
import langchain
import pinecone
from langchain.document_loaders import PyPDFDirectoryLoader
from langchain.text_splitter import RecursiveCharacterTextSplitter
from langchain.embeddings.openai import OpenAIEmbeddings
from langchain.vectorstores import Pinecone
from langchain.llms import OpenAI

# %%
import os

# %%
def read_pdf(directory):
    file_loader = PyPDFDirectoryLoader(directory)
    documents = file_loader.load()
    return documents

# %%
docs = read_pdf('documents/')
docs
# Out:
# [Document(page_content='FACT SHEET - SEPTEMBER 2023\nMr. Rajeev Thakkar\nCIO & DirectorWhy we did what we did...\nRajeev Thakkar\nChief Investment Oﬃcer and Director\nScheme Page No.\nParag Parikh Flexi Cap Fund\nParag Parikh Tax Saver Fund\nParag Parikh Conservative Hybrid Fund\nParag Parikh Liquid Fund2\n4\n6\n9(Please visit Page 2) \nForeign equity investment \nThe fund invests in foreign equity securities. Since investors in PPFCF look for capital investment and returns in Rupee \nterms, PPFCF also looks at delivering in Rupee terms. PPFCF hedges most of the currency exposure using currency \nfutures.\nOutlookAbout Parag Parikh Flexi Cap Fund \nParag Parikh Flexi Cap Fund (PPFCF) is an open ended equity oriented scheme with flexibility to invest a minimum of \n65% in Indian equities and up to 35% in overseas equity security and domestic debt / money market securities.\nWe continue to look at individual investments on their own merits and will not hesitate to invest if an opportun
# ...

# %%
len(docs)
# Out:
# 16

# %%
def chunk_data(docs, chunk_size=800, chunk_overlap=50):
    textsplitter = RecursiveCharacterTextSplitter(chunk_size=chunk_size, chunk_overlap=chunk_overlap)
    chunked_doc = textsplitter.split_documents(docs)
    return chunked_doc

# %%
documents = chunk_data(docs)
len(documents)
# Out:
# 93

# %%
embeddings = OpenAIEmbeddings(api_key=os.environ['OPENAI_API_KEY'])
embeddings
# Out:
# OpenAIEmbeddings(client=<openai.resources.embeddings.Embeddings object at 0x000001F051A0BF50>, async_client=<openai.resources.embeddings.AsyncEmbeddings object at 0x000001F051A4DF10>, model='text-embedding-ada-002', deployment='text-embedding-ada-002', openai_api_version='', openai_api_base=None, openai_api_type='', openai_proxy='', embedding_ctx_length=8191, openai_api_key='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', openai_organization=None, allowed_special=set(), disallowed_special='all', chunk_size=1000, max_retries=2, request_timeout=None, headers=None, tiktoken_enabled=True, tiktoken_model_name=None, show_progress_bar=False, model_kwargs={}, skip_empty=False, default_headers=None, default_query=None, retry_min_seconds=4, retry_max_seconds=20, http_client=None)

# %%
vectors = embeddings.embed_query("what is expense ratio ?")
len(vectors)
# Out:
# 1536

# %%
#creating vector DB
pc = Pinecone(api_key="4473ce6b-0252-4afd-b3bb-50f730a2a61f")
index_name = pc.Index("langchainvector")

# %%
pinecone.init(
    api_key="4473ce6b-0252-4afd-b3bb-50f730a2a61f",
    environment="gcp-starter"
)
index_name="langchainvector"
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 pinecone.init(
#       2     api_key="4473ce6b-0252-4afd-b3bb-50f730a2a61f",
#       3     environment="gcp-starter"
#       4 )
#       5 index_name="langchainvector"
#
# File c:\Users\Acer\VS Code Projects\pylibnew\Lib\site-packages\pinecone\deprecation_warnings.py:38, in init(*args, **kwargs)
#      11     example = """
#      12     import os
#      13     from pinecone import Pinecone, ServerlessSpec
#    (...)
#      29         )
#      30 """
#      31     msg = f"""init is no longer a top-level attribute of the pinecone package.
#      32
#      33 Please create an instance of the Pinecone class instead.
#    (...)
#      36 {example}
#      37 """
# ---> 38     raise AttributeError(msg)
#
# AttributeError: init is no longer a top-level attribute of the pinecone package.
#
# ...
